# %%
import pandas as pd

# %%
df = pd.read_csv("train.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# ### Identifying the missing values

# %%
df.isna()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ### Steps:
#
# - Remove the missing data row
# - Manually fill the cells
# - Mean, Median Mode used where there are missing values
#     - Mode: Use when categorical Data
#     - When the data is widely scattered we use Median
#     - When the data isnt skewed much we use Mean and Its the best!!
# - Categorical Data can be filled by Unknown or U!!
# - Predict the missing values. (Skippin it in this lecture)

# %%
df = df.dropna()

# %%
df.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df.shape
# Out:
# (183, 12)

# %%
df1 = pd.read_csv("train.csv")

# %%
df1.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
mean = df1["Age"].mean()
mean
# Out:
# 29.69911764705882

# %%
df1["Age"] = df1["Age"].fillna(mean)

# %%
df1.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df1["Cabin"].value_counts()
# Out:
# C23 C25 C27    4
# G6             4
# B96 B98        4
# C22 C26        3
# F2             3
#               ..
# E38            1
# B94            1
# B19            1
# A34            1
# A32            1
# Name: Cabin, Length: 147, dtype: int64

# %%
df1["Cabin"] = df1["Cabin"].fillna("C23")

# %%
df1.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       2
# dtype: int64

# %%
df1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   C23        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   C23        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   C23        S

# %%
df1["Embarked"] = df1["Embarked"].fillna(df1["Embarked"].mode()[0])

# %%
df1.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %% [markdown]
# #### Forward fill (Previous value to the missing value)
#
# #### df = df.fillna(method="pad")

# %%
df3 = pd.read_csv("train.csv")

# %%
df3.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df3.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ###### forward fill has two method
# 1. pad
# 2. ffill

# %%
df3["Age"]=df3["Age"].fillna(method = "pad")  #forwardfill

# %%
df3.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df3["Age"].head()
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: Age, dtype: float64

# %% [markdown]
# #### bfill
# #### Backward Fill

# %%
df3["Cabin"]=df3["Cabin"].fillna(method = "bfill")  #backwardfill

# %%
df3.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          1
# Embarked       2
# dtype: int64

# %%
df3["Embarked"] = df3["Embarked"].fillna(method = "bfill")
df3.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          1
# Embarked       0
# dtype: int64

# %%
df3["Cabin"]=df3["Cabin"].fillna(method = "pad")  #forwardfill

# %%
df3.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %% [markdown]
# ##### df3 = df3.replace({"Name":"FullName"})
# ##### ["Name"] = df["Name"].replace({"Braund, Mr. Owen Harris":"Bruno James"})

# %%
df3.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   C85        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250  C123        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   E46        S

# %%
df3["Name"] = df3["Name"].replace({"Braund, Mr. Owen Harris":"Bruno James"})

# %%
df3.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                                        Bruno James    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   C85        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250  C123        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   E46        S

# %% [markdown]
# ### Group By

# %%
gender = df3.groupby("Sex")

# %%
print(gender)

# %%
print(gender.groups)
# Out:
# {'female': [1, 2, 3, 8, 9, 10, 11, 14, 15, 18, 19, 22, 24, 25, 28, 31, 32, 38, 39, 40, 41, 43, 44, 47, 49, 52, 53, 56, 58, 61, 66, 68, 71, 79, 82, 84, 85, 88, 98, 100, 106, 109, 111, 113, 114, 119, 123, 128, 132, 133, 136, 140, 141, 142, 147, 151, 156, 161, 166, 167, 172, 177, 180, 184, 186, 190, 192, 194, 195, 198, 199, 205, 208, 211, 215, 216, 218, 229, 230, 233, 235, 237, 240, 241, 246, 247, 251, 254, 255, 256, 257, 258, 259, 264, 268, 269, 272, 274, 275, 276, ...], 'male': [0, 4, 5, 6, 7, 12, 13, 16, 17, 20, 21, 23, 26, 27, 29, 30, 33, 34, 35, 36, 37, 42, 45, 46, 48, 50, 51, 54, 55, 57, 59, 60, 62, 63, 64, 65, 67, 69, 70, 72, 73, 74, 75, 76, 77, 78, 80, 81, 83, 86, 87, 89, 90, 91, 92, 93, 94, 95, 96, 97, 99, 101, 102, 103, 104, 105, 107, 108, 110, 112, 115, 116, 117, 118, 120, 121, 122, 124, 125, 126, 127, 129, 130, 131, 134, 135, 137, 138, 139, 143, 144, 145, 146, 148, 149, 150, 152, 153, 154, 155, ...]}

# %%
cabins = df3.groupby("Cabin")

# %%
cabins.groups
# Out:
# {'A10': [582, 583], 'A14': [474, 475], 'A16': [551, 552, 553, 554, 555, 556], 'A19': [276, 277, 278, 279, 280, 281, 282, 283, 284], 'A20': [592, 593, 594, 595, 596, 597, 598, 599], 'A23': [628, 629, 630], 'A24': [863, 864, 865, 866, 867], 'A26': [646, 647], 'A31': [206, 207, 208, 209], 'A32': [184, 185], 'A34': [439, 440, 441, 442, 443, 444, 445], 'A36': [803, 804, 805, 806], 'A5': [93, 94, 95, 96], 'A6': [22, 23], 'A7': [171, 172, 173, 174], 'B101': [731, 732, 733, 734, 735, 736, 737], 'B102': [810, 811, 812, 813, 814, 815], 'B18': [328, 329, 521, 522, 523], 'B19': [167, 168, 169, 170], 'B20': [690, 780, 781], 'B22': [540, 743, 744, 745], 'B28': [56, 57, 58, 59, 60, 61, 824, 825, 826, 827, 828, 829], 'B3': [777, 778, 779], 'B30': [53, 54], 'B35': [367, 368, 369, 633, 634, 635, 636, 637, 638, 639, 640, 641], 'B37': [487], 'B38': [528, 529, 530, 531, 532, 533, 534, 535, 536], 'B39': [537, 538, 539], 'B4': [194], 'B41': [586, 587], 'B42': [880, 881, 882, 883, 884, 885, 886, 887], 'B49'
# ...

# %%
cabins.get_group("D20")
# Out:
#      PassengerId  Survived  Pclass  \
# 493          494         0       1
# 494          495         0       3
# 495          496         0       3
# 496          497         1       1
# 588          589         0       3
# 589          590         0       3
# 590          591         0       3
# 591          592         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 493                          Artagaveytia, Mr. Ramon    male  71.0      0
# 494                       Stanley, Mr. Edward Roland    male  21.0      0
# 495                            Yousseff, Mr. Gerious    male  21.0      0
# 496                   Eustis, Miss. Elizabeth Mussey  female  54.0      1
# 588                            Gilinski, Mr. Eliezer    male  22.0      0
# 589                              Murdlin, Mr. Joseph    male  22.0      0
# 590                             Rintamaki, Mr. Matti    male  35.0      0
# ...

# %%
gender.sum()
# Out:
#         PassengerId  Survived  Pclass       Age  SibSp  Parch        Fare
# Sex
# female       135343       233     678   8926.92    218    204  13966.6628
# male         262043       109    1379  17430.25    248    136  14727.2865

# %%
gender.mean()
# Out:
#         PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# Sex
# female   431.028662  0.742038  2.159236  28.429682  0.694268  0.649682
# male     454.147314  0.188908  2.389948  30.208406  0.429809  0.235702
#
#              Fare
# Sex
# female  44.479818
# male    25.523893

# %%
gender.count()
# Out:
#         PassengerId  Survived  Pclass  Name  Age  SibSp  Parch  Ticket  Fare  \
# Sex
# female          314       314     314   314  314    314    314     314   314
# male            577       577     577   577  577    577    577     577   577
#
#         Cabin  Embarked
# Sex
# female    314       314
# male      577       577

# %%
gender.min()
# Out:
#         PassengerId  Survived  Pclass                              Name   Age  \
# Sex
# female            2         0       1  Abbott, Mrs. Stanton (Rosa Hunt)  0.75
# male              1         0       1               Abbing, Mr. Anthony  0.42
#
#         SibSp  Parch  Ticket  Fare Cabin Embarked
# Sex
# female      0      0  110152  6.75   A14        C
# male        0      0  110413  0.00   A10        C

# %%
gender.max()
# Out:
#         PassengerId  Survived  Pclass  \
# Sex
# female          889         1       3
# male            891         1       3
#
#                                                 Name   Age  SibSp  Parch  \
# Sex
# female  de Messemaeker, Mrs. Guillaume Joseph (Emma)  65.0      8      6
# male                     van Melkebeke, Mr. Philemon  80.0      8      5
#
#            Ticket      Fare Cabin Embarked
# Sex
# female  WE/P 5735  512.3292    G6        S
# male    WE/P 5735  512.3292     T        S
