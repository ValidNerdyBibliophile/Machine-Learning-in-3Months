# %% [markdown]
# ### Open CV

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread("img.jpg")

# %%
img
# Out:
# array([[[236, 237, 211],
#         [236, 237, 211],
#         [236, 237, 211],
#         ...,
#         [210, 151,  51],
#         [206, 147,  48],
#         [221, 162,  63]],
#
#        [[236, 237, 211],
#         [236, 237, 211],
#         [236, 237, 211],
#         ...,
#         [210, 151,  51],
#         [206, 147,  48],
#         [221, 162,  63]],
#
#        [[236, 237, 211],
#         [236, 237, 211],
#         [236, 237, 211],
#         ...,
#         [210, 151,  51],
#         [206, 147,  48],
#         [221, 162,  63]],
#
#        ...,
#
#        [[142,  70,  30],
#         [142,  70,  30],
#         [142,  70,  30],
#         ...,
#         [141,  72,  29],
#         [139,  70,  27],
#         [150,  81,  38]],
#
#        [[142,  70,  30],
#         [142,  70,  30],
#         [142,  70,  30],
#         ...,
#         [141,  72,  29],
#         [139,  70,  27],
#         [150,  81,  38]],
#
#        [[142,  70,  30],
#         [142,  70,  30],
#         [142,  70,  30],
#         ...,
#         [141,  72,  29],
#         [139,  70,  27],
#         [150,  81,  38]]], dtype=uint8)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gray)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gray, cmap = "gray")
