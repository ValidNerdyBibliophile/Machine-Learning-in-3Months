# %% [markdown]
# #Statistics
#
# #Measure of Dispersion
# Dispersion is a way of describing how data is spread around an average value.
# Data set have large diffrences between data values then data set is said widely scatterted data set
# Data values are close to each other the data set is said to be tightly clustered data set.
# Eg -
# 55,57,55,52,56

# %% [markdown]
# #Range
# The diffrence between largest and smallest data value in given data set is known as Range of given data set
#  For example , if we had data set as 1,,3,54,8,1,5,1
#  Range = 54-1

# %% [markdown]
# #Mean Deviation
# Average of absolute diffrences from the mean is known as mean deviation.
#
# 1) Calculate the mean
#
# 2) Find the each data value from the mean
#
# ![4dd3b5d5-ad98-40b3-a493-cfb42e5ce124.jfif](data:image/jpeg;base64,...)3) Add the value you calculated in second step and divide by the total number od data values
#
# M.D = E |xi-x(bar)|/N

# %% [markdown]
# #Variance
#
# The variance is the average of squared diffrences from the mean.
#
# 1) Calculate the mean of data values
#
# 2) Find out the absolute diffrence of each data value from the mean
#
# 3) square each absolute diffrence you find
#
# 4) Take the mean of all squared values from step 3
#
# ![cebace90-d599-447b-8565-de415714f93e.jfif](data:image/jpeg;base64,...)

# %% [markdown]
# #Standard Deviation
#
# The Standard Deviation is the square root of variance.
#
# ![40f1c508-fd2b-40b7-b302-f25a0cf179f6.jfif](data:image/jpeg;base64,...)

# %% [markdown]
# #Measure of Central Tendancy
#
# Measure of central tendancy ![median.jfif](data:image/jpeg;base64,...)

# %% [markdown]
# #Mode
#
# ![mode.jfif](data:image/jpeg;base64,...)

# %% [markdown]
# #Skewness
#
# Is the measure of symmetr or asymmetry of data distribution
#
# ![Skwness.jfif](data:image/jpeg;base64,...)

# %% [markdown]
# ![skwness.png](data:image/png;base64,...)

# %% [markdown]
# #Positive and Negative Skewness
# ![image.png](data:image/png;base64,...)
